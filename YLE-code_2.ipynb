# %%
#!/usr/bin/env python
# -*- coding: UTF8 -*-
# @See http://www.python.org/dev/peps/pep-0263

#######
# ABOUT
#######

# Script for scraping Etuovi data.

########
# AUTHOR
########

# Teemo Tebest (teemo.tebest@gmail.com)

#########
# LICENSE
#########

# CC-BY-SA 4.0 Yle Uutiset / Teemo Tebest

#######
# USAGE
#######

# python scraper_vuokraovi.py [start_page] [end_page]

# See:
# - http://www.vuokraovi.com/vuokra-asunnot
# - http://www.vero.fi/fi-FI/Syventavat_veroohjeet/Verohallinnon_paatokset/Verohallinnon_paatos_vuodelta_2012_toimi%2819141%29 

#################
# VERSION HISTORY
#################

# Version 1.0
# - Initial version.

#############################################################

# Import pymongo for storing up values
import pymongo
# Import requests for making http requests.
import requests
# Import BeautifulSoup for handling html contents.
from bs4 import BeautifulSoup
# Import re for making regular experssions.
import re
# Import sys for reading arguments.
import sys
print("\033[1mProvide a starting and ending page.\033[0m\nUsage \"python scraper_etuovi.py [start_page] [end_page]\"")
# Out:
# Provide a starting and ending page.
# Usage "python scraper_etuovi.py [start_page] [end_page]"

# %%
#This is what will be added after http://www.vuokraovi.com/vuokra-asunnot?page=
#I think the + 1 is there so that if there is for example 43 pages our code will try to access 44 and shut down.
# not sure though
start_page = 1
end_page = 2 + 1

# %%
# Create mongodb connection
from pymongo import MongoClient
connection = MongoClient('localhost', 27017)
#connection = Connection('localhost', 27017)

database = connection.housing_data

table = database.etuovi

#table.remove() to remove everything

cookie = {'org.springframework.mobile.device.site.CookieSitePreferenceRepository.SITE_PREFERENCE':'NORMAL','JSESSIONID':'183EE2F12C128B603790A0D5D1558022','evid_0006':'87ccc59d-4b80-489f-98cf-be92d6591fa6','evid_0006_ref':'false','adptseg_0006':'kv1001#a-kv1002#c-kv1003#d-kv1004#d-kv1005#c-kv1006#a:b-kv1008#c-kv1009#17-kv1010#b-kv1011#f-kv1012#c-kv1013#a-kv1016#1:11:13:2:7-kv1017#2-','adptset_0006':'1','evid_0006_set':'2','__utma':'82691985.304271103.1385626909.1385642039.1385658686.4','__utmb':'82691985.9.8.1385658723878','__utmc':'82691985','__utmz':'82691985.1385626909.1.1.utmcsr=kuluttaja.etuovi.com|utmccn=(referral)|utmcmd=referral|utmcct=/crometapp/product/realties/common/public/frontpage2/search_in_progress_to_vuokraovi.jsp','slbp_80':'2265258762.20480.0000','slbp_443':'2265258762.47873.0000'}

data_added = 0
data_existed = 0

# %%
# First we get data from the pages that list the apartments. 
# Ex. http://www.vuokraovi.com/vuokra-asunnot?page=1
for page in range(start_page, end_page):
  if (start_page > 0):
    print ('Parsing page: ', str(page))
    html = requests.post('http://www.vuokraovi.com/vuokra-asunnot?page=' + str(page), cookies=cookie, data={'listorder':11, 'perpage':30})

    parsed_html = BeautifulSoup(html.text,'html.parser')
    #print(parsed_html.find_all(text = "url"))
    #print(parsed_html.find(a='url'))
    # This is the thing we want I think: 
    #<!--<a itemprop="url" href="/vuokra-asunto/vaasa/keskusta/kerrostalo/660426?entryPoint=fromSearch&rentalIndex=1" 
    #class="list-item-link">-->
    print(parsed_html.prettify())

    rows = parsed_html.find('table', {'id':'itemList'}).find('tbody').findAll('tr', {'class': ['evenRow', 'oddRow']})

    row_index = 0
    for row in rows:
      row_index = row_index + 1
      column_index = 0
      apartment = dict() 
      columns = row.findAll('td')
      for column in columns:
        column_index = column_index + 1
        # apartment image.
        if column_index == 1:
          m = re.search('(\d+)\?entryPoint', column.find('div').find('a')['href'])
          apartment['aid'] = m.group(1)
          apartment['url'] = column.find('div').find('a')['href']
        # apartment type.
        if column_index == 2:
          apartment['type'] = column.text
        # Apartment size.  
        if column_index == 3:
          apartment['size'] = column.text
          if apartment['size'] == '':
            apartment['size'] = '0'
          if apartment['size'] == 'm2':
            apartment['size'] = '0'
        # Apartment rent.  
        if column_index == 4:
          apartment['rent'] = column.text
          if apartment['rent'] == '':
            apartment['rent'] = '0'
        # Apartment location.  
        if column_index == 6:
          apartment['location'] = column.text
      if apartment['aid'] != '':
        if not table.find({'aid': apartment['aid']}).count():
          data_added = data_added + 1
          # Push the collected data to db.
          table.insert({
            'build_year': '', 
            'rental_service': '', 
            'aid': apartment['aid'], 
            'type': apartment['type'],
            'size': apartment['size'],
            'url': apartment['url'],
            'size_nr': float(re.sub(r'[^0-9.]', '', apartment['size'].replace('m2', '').replace(',', '.'))),
            'rent': apartment['rent'],
            'rent_nr': float(re.sub(r'[^0-9.]', '', apartment['rent'].replace(' &euro;/kk', '').replace(' &euro;/vko', '').replace(',', '.'))),
            'location': apartment['location']
          })
        else:
          data_existed = data_existed + 1

print ('\033[1mNew records:\033[0m ' , str(data_added))
print ('\033[1mExisting records:\033[0m ' , str(data_existed))

print ('\n\033[1mWill now search for additional data.\033[0m\n')
# Out:
# Parsing page:  1
# []
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]>         <html class="no-js ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <script>
#    // Picture element HTML5 shiv
#             document.createElement( "picture" );
#   </script>
#   <script async="" src="/js/common/picturefill-3.0.1.min.js">
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Vuokra-asunnot - vuokrakohteet - Vuokraovi.com
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="Vuokraovi.com löytää vapaat vuokra-asunnot alueelta {0} nopeasti. Tee haku nyt ja löydä vuokra-asunto jo tänään!" name="description"/>
#    <meta content="vuokra, asunto, vuokra-asunto, vuokra-asunnot, tontit, autopaikat, kimppakämpät, vuokrataan, vuokraus, asunnot" name="keywords"/>
#    <meta content="Vuokraovi.com löytää vapaat vuokra-asunnot alueelta vuokrakohteet nopeasti. Tee haku nyt ja löydä vuokra-asunto jo tänään!" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="//d2ue5ppt0wsjaa.cloudfront.net/600x450,fit/vuokraovimedia/images/150/761/710/923/150761710923048_original.jpg" property="og:image"/>
#    <meta content="Alma Mediapartners Oy" name="author"/>
#    <meta content="Copyright (c) Alma Mediapartners Oy" name="copyright"/>
#    <meta content="NOODP" name="robots"/>
#    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#    <meta content="width=device-width, initial-scale=1.0, user-scalable=1, shrink-to-fit=no" id="viewport-meta" name="viewport"/>
#    <meta content="no" name="msapplication-tap-highlight">
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" type="text/css"/>
#     <link href="/css/vuokraovi.css" rel="stylesheet">
#      <script src="/js/common/jquery-1.10.2.js" type="text/javascript">
#      </script>
#      <script>
#       (function() {
#     if ("-ms-user-select" in document.documentElement.style && navigator.userAgent.match(/IEMobile\/10\.0/)) {
#         var msViewportStyle = document.createElement("style");
#         msViewportStyle.appendChild(
#             document.createTextNode("@-ms-viewport{width:auto!important}")
#         );
#         document.getElementsByTagName("head")[0].appendChild(msViewportStyle);
#     } else if ( navigator.userAgent.match(/iPad/i) ) {
#         var viewport = document.getElementById('viewport-meta');
#         /* TODO: VUOKRAOVI-5292 */
#         //viewport.setAttribute("content", "initial-scale=0.78");
#         //viewport.setAttribute("content", "width=1200px");
#     }
#  })();
#      </script>
#      <!--[if lte IE 7]><script src="js/common/iconfont-lte-ie7.js"></script><![endif]-->
#      <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#      <!--[if lt IE 9]>
#     <script src="js/common/html5shiv.js" async></script>
#     <script src="js/common/respond.min.js" async></script>
# <![endif]-->
#      <!-- Favicons -->
#      <link href="/img/assets/ico/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#      <link href="/img/assets/ico/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#      <link href="/img/assets/ico/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
#      <link href="/img/assets/ico/favicon.png" rel="shortcut icon"/>
#      <script type="text/javascript">
#       window.showEnreach = false;
#   window.showMadsTags = false;
#   window.emediateDomain = 'https://eas.almamedia.fi';
#   window.showEmediate = false;
#      </script>
#      <script>
#       window.digitalData = window.digitalData ||{};
#     window.digitalData = {"pageInstanceId":"1507618039490_vo_prod","version":{"almaVersion":"1.4","specificationVersion":"1.0"},"page":{"pageInfo":{"pageId":"1507618039490","sysEnv":"undefined","pageTitle":"undefined","language":"fi_FI","geoRegion":"FI","publisher":"Alma Mediapartners Oy, Vuokraovi.com","locationProtocol":"https","locationHost":"www.vuokraovi.com","locationPathName":"/vuokra-asunnot","locationHref":"undefined","referrer":"undefined"},"category":{"primaryCategory":"resultspage","subCategory":"undefined"},"attributes":{"environment":"prod","viewport":"undefined","width":null,"userAgentHeader":"python-requests/2.14.2","contentCharge":"free","adTargetingParameters":[{"cat1":"vo_vuokra_asunnot"}]}},"product":null};
#
#     resolveSysEnv = function(width) {
#       if (width >= 1000) {
#         return "desktop";
#       }
#
#       return "mobile";
#     };
#
#     resolveViewport = function(width) {
#       if (width >= 1000) {
#         return "desktop";
#       } else if (width >= 768) {
#         return "tablet";
#       }
#
#       return "mobile";
#     };
#
#     var postProcessDigitalData = function(object) {
#       var windowWidth = jQuery(window).width();
#       // Set window width
#       object.page.attributes.width = windowWidth;
#       // Set viewport
#       object.page.attributes.viewport = resolveViewport(windowWidth);
#       // Set sysEnv
#       object.page.pageInfo.sysEnv = resolveSysEnv(windowWidth);
#       // Set locationHref
#       object.page.pageInfo.locationHref = window.location.href;
#       // Set referrer
#       object.page.pageInfo.referrer = document.referrer;
#       // Set pageTitle
#       object.page.pageInfo.pageTitle = document.title;
#
#       if (object.product && object.product.length === 1) {
#         // Set productName
#         object.product[0].productInfo.productName = document.title;
#         // Set productDescription
#         object.product[0].productInfo.description = jQuery("meta[name='description']").attr('content');
#       }
#
#       object = removeUndefinedValuesFromObject(object);
#       return object;
#     };
#
#     function removeUndefinedValuesFromObject(object) {
#       for (var property in object) {
#         if (object.hasOwnProperty(property)) {
#           if (typeof object[property] == "object" && object[property] != null){
#             removeUndefinedValuesFromObject(object[property]);
#           }else{
#             if (object[property] === undefined  || object[property] === "undefined" || object[property] === null) {
#               delete object[property];
#             }
#           }
#         }
#       }
#       return object;
#     }
#
#
#     digitalData = postProcessDigitalData(digitalData);
#      </script>
#      <meta content="search.full.result" name="currentPage">
#       <link href="https://www.vuokraovi.com/vuokra-asunnot" rel="canonical"/>
#       <link href="https://www.vuokraovi.com/vuokra-asunnot?locale=en" hreflang="en" rel="alternate"/>
#       <link href="https://www.vuokraovi.com/vuokra-asunnot" hreflang="fi" rel="alternate"/>
#       <link href="https://www.vuokraovi.com/vuokra-asunnot?page=2" rel="next"/>
#       <link href="/css/renewal-print.css" media="print" rel="stylesheet" type="text/css"/>
#       <link href="/css/common/swiper-3.4.1.min.css" rel="stylesheet"/>
#       <script src="/js/common/swiper.jquery-3.4.1.min.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        var isScrollToPreviousListPosition = false;
#       </script>
#       <script src="//code3.adtlgc.com/js/alma_init_cjs.js" type="text/javascript">
#       </script>
#       <script src="//code3.adtlgc.com/js/alma_ar.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        window.cat1 = 'vo_vuokra_asunnot';
#             window.sw = '';
#             window.locationParam = '';
#       </script>
#       <script type="text/javascript">
#        function saveRentalSearchAndShareOnFacebook(){
# 	             $.ajax({
# 	                   type : "GET",
#                      async: false,
# 	                   url: "/main/saverentalsearchAjax.action",
#                      dataType: 'text',
# 	                   success: (function( result ) {
# 	                       shareOnFacebookWithParam(encodeURIComponent(result));
# 	                     }),
# 	                   error: function (request, status, error) {
#                            console.log("status: " + status + ", error: " + error)
# 	                   }
# 	                 });
# 	           }
#
# 	         function saveRentalSearchAndShareOnTwitter(){
#
# 	               $.ajax({
# 	                     type : "GET",
#                        async: false,
# 	                     url: "/main/saverentalsearchAjax.action",
#                        dataType: 'text',
# 	                     success: (function( result ) {
# 	                         shareOnTwitterWithParam(encodeURIComponent(result));
# 	                       }),
# 	                     error: function (request, status, error) {
# 	                     }
# 	                   });
# 	             }
#
# 	         function saveRentalSearchAndShareOnWhatsApp(text){
#                  $.ajax({
#                        type : "GET",
#                        async: false,
#                        url: "/main/saverentalsearchAjax.action",
#                        data: "",
#                        dataType: 'text',
#                        success: (function( result ) {
#                     	     var whatsAppUrl = 'whatsapp://send?text=' + encodeURIComponent(text + ': '  + result + '&utm_source=whatsapp&utm_medium=jaa_haku&utm_campaign=whatsapp-share') + '',
#                            whatsAppFallbackLinkAndroid = 'intent://scan/#Intent;package=com.whatsapp;end',
#                            whatsAppFallbackLinkIOS = 'http://itunes.apple.com/app/id310633997';
#
#                            openApp(whatsAppUrl, whatsAppFallbackLinkAndroid, whatsAppFallbackLinkIOS);
#
#                     	//   window.location.href  = 'whatsapp://send?text=' + encodeURIComponent(text + ': ' + result + '?utm_source=whatsapp&utm_medium=kohdesivu&utm_campaign=whatsapp-share');
#                          }),
#                        error: function (request, status, error) {
#                            alert("error: " +error);
#                        }
#                      });
#                }
#       </script>
#       <script type="text/javascript">
#        var _gaq = _gaq || [];
#                 _gaq.push(
#                         ['_setAccount', 'UA-3459490-1'],
#                         ['_trackPageview']
#                         );
#
#
#
#
#                         var searchType = 'Advanced Search';
#
#
#                         // All search criteria in one row
#                         // Search criteria splitted into multiple rows (usually "Type:value" structure like Alue:Tampere (Area:Tampere))
#                         _gaq.push(
#                                 ['_trackEvent', searchType, 'Search-criteria', 'vuokrakohteet', ,true],
#                 ['_trackEvent', searchType, 'Search-criterion', 'Vuokrakohteet', ,true]
#                         );
#                                 (function() {
#                                     var ga = document.createElement('script');
#                                     ga.type = 'text/javascript';
#                                     ga.async = true;
#                                     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#                                     var s = document.getElementsByTagName('script')[0];
#                                     s.parentNode.insertBefore(ga, s);
#                                 })();
#       </script>
#       <script src="//nexus.ensighten.com/alma/vuokraovicom/Bootstrap.js" type="text/javascript">
#       </script>
#      </meta>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- Side menu -->
#   <div class="snap-drawers visible-xs" id="snapDrawers">
#    <div class="snap-drawer snap-drawer-left" id="leftMenu">
#     <a class="icon-home left-menu-top-icon" href="/">
#     </a>
#     <ul class="left-menu-list">
#      <li>
#       <a href="/haku/vuokra-asunnot">
#        Vuokra-asunnot
#       </a>
#      </li>
#      <li>
#       <a href="https://www.gofinland.fi/vuokramokit">
#        Vuokramökit
#       </a>
#      </li>
#      <li>
#       <a href="/vuokranantajille">
#        Vuokranantajille
#       </a>
#      </li>
#      <li>
#       <a href="/login.action">
#        Kirjaudu sisään
#       </a>
#      </li>
#      <li>
#       <a href="/secured/register.action">
#        Rekisteröidy
#       </a>
#      </li>
#     </ul>
#     <hr class="margin-left-10 margin-right-10"/>
#     <ul class="list-unstyled list-inline list-languages">
#      <li class="language language-fi active">
#       <a href="?locale=fi" title="Suomeksi">
#        <span style="display:none">
#         Suomeksi
#        </span>
#       </a>
#      </li>
#      <li class="language language-en ">
#       <a href="?locale=en" title="In English">
#        <span style="display:none">
#         In English
#        </span>
#       </a>
#      </li>
#     </ul>
#     <img alt="Alma Media" class="side-menu-alma-logo" onerror="this.onerror=null; this.src='/img/logo/footer_alma_logo_white.png'" src="/img/logo/footer_alma_logo_white.svg"/>
#    </div>
#    <div class="snap-drawer snap-drawer-right">
#    </div>
#   </div>
#   <div class="snap-content" id="content">
#    <nav class="navbar navbar-default" role="navigation">
#     <div class="container pad-right-0 pad-left-0 flexible-container">
#      <div class="row">
#       <div class="col-xs-12">
#        <!-- ALMA CR WIDGET: -->
#        <!--[if gte IE 9]><!-->
#        <div class="ALMACR-container" data-almacr-widget-id="5577db4db922930e0800001e" data-almacr-widget-publisher-id="5577db0eb922930e0800001d" data-almacr-widget-template-version="0.0.1" id="ALMACR-container-ALMACR-widget-5577db4db922930e0800001e">
#         <style class="ALMACR-base-css">
#          #ALMACR-container-ALMACR-widget-5577db4db922930e0800001e{display:block;overflow:hidden;margin:0;padding:0;border:0;position:static;top:auto;bottom:auto;left:auto;right:auto;width:100%;height:auto;-webkit-box-sizing:content-box;box-sizing:content-box}#ALMACR-widget-5577db4db922930e0800001e{overflow:hidden;-webkit-box-sizing:content-box;box-sizing:content-box;text-align:left;vertical-align:baseline;line-height:normal;font-style:normal;font-variant:normal;font-weight:400;font-stretch:normal;font-size:medium;font-family:sans-serif;text-transform:none;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}#ALMACR-widget-5577db4db922930e0800001e *,#ALMACR-widget-5577db4db922930e0800001e :after,#ALMACR-widget-5577db4db922930e0800001e :before{-webkit-box-sizing:inherit;box-sizing:inherit}#ALMACR-widget-5577db4db922930e0800001e *{margin:0;padding:0;border:0;height:auto;width:auto;position:static;top:auto;bottom:auto;left:auto;right:auto;overflow:visible;background-image:none;background-position:0 0;-webkit-background-size:auto auto;background-size:auto auto;background-repeat:repeat;-webkit-background-origin:padding-box;background-origin:padding-box;-webkit-background-clip:border-box;background-clip:border-box;background-color:transparent;-webkit-box-shadow:none;box-shadow:none;text-align:inherit;vertical-align:baseline;line-height:inherit;font-style:inherit;font-variant:inherit;font-weight:inherit;font-stretch:inherit;font-size:inherit;line-height:inherit;font-family:inherit;text-transform:inherit}#ALMACR-widget-5577db4db922930e0800001e tbody,#ALMACR-widget-5577db4db922930e0800001e tfoot,#ALMACR-widget-5577db4db922930e0800001e thead{vertical-align:middle}#ALMACR-widget-5577db4db922930e0800001e tbody *,#ALMACR-widget-5577db4db922930e0800001e tfoot *,#ALMACR-widget-5577db4db922930e0800001e thead *{vertical-align:inherit}#ALMACR-widget-5577db4db922930e0800001e b,#ALMACR-widget-5577db4db922930e0800001e strong{font-weight:700}#ALMACR-widget-5577db4db922930e0800001e dfn,#ALMACR-widget-5577db4db922930e0800001e em,#ALMACR-widget-5577db4db922930e0800001e i{font-style:italic}#ALMACR-widget-5577db4db922930e0800001e article,#ALMACR-widget-5577db4db922930e0800001e aside,#ALMACR-widget-5577db4db922930e0800001e details,#ALMACR-widget-5577db4db922930e0800001e figcaption,#ALMACR-widget-5577db4db922930e0800001e figure,#ALMACR-widget-5577db4db922930e0800001e footer,#ALMACR-widget-5577db4db922930e0800001e header,#ALMACR-widget-5577db4db922930e0800001e hgroup,#ALMACR-widget-5577db4db922930e0800001e nav,#ALMACR-widget-5577db4db922930e0800001e section,#ALMACR-widget-5577db4db922930e0800001e summary{display:block}#ALMACR-widget-5577db4db922930e0800001e audio,#ALMACR-widget-5577db4db922930e0800001e canvas,#ALMACR-widget-5577db4db922930e0800001e progress,#ALMACR-widget-5577db4db922930e0800001e video{display:inline-block;vertical-align:baseline}#ALMACR-widget-5577db4db922930e0800001e audio:not([controls]){display:none;height:0}#ALMACR-widget-5577db4db922930e0800001e [hidden],#ALMACR-widget-5577db4db922930e0800001e template{display:none}#ALMACR-widget-5577db4db922930e0800001e a{background:0 0}#ALMACR-widget-5577db4db922930e0800001e a:active,#ALMACR-widget-5577db4db922930e0800001e a:hover{outline:0}#ALMACR-widget-5577db4db922930e0800001e svg:not(:root){overflow:hidden}#ALMACR-widget-5577db4db922930e0800001e :after,#ALMACR-widget-5577db4db922930e0800001e :before{content:normal}#ALMACR-widget-5577db4db922930e0800001e h5,#ALMACR-widget-5577db4db922930e0800001e h6{font-weight:700}#ALMACR-widget-5577db4db922930e0800001e ol,#ALMACR-widget-5577db4db922930e0800001e ul{padding:0 0 0 40px;margin:1em 0;list-style-position:outside}#ALMACR-widget-5577db4db922930e0800001e ul{list-style-type:disc}#ALMACR-widget-5577db4db922930e0800001e ol{list-style-type:decimal}
#         </style>
#         <script>
#          !function(A,d){A.ALMACR=A.ALMACR||{},A.ALMACR.host=d.URL,A.ALMACR.widgets=A.ALMACR.widgets||{},A.ALMACR.widgets["5577db4db922930e0800001e"]={},widget=A.ALMACR.widgets["5577db4db922930e0800001e"],widget.scripts=widget.scripts||[]}(window,document);
#         </script>
#         <div>
#          <article class="ALMACR-widget" id="ALMACR-widget-5577db4db922930e0800001e">
#           <script data-almacr-widget-script-id="b8w7833" data-almacr-widget-script-source-basename="main.js" data-almacr-widget-script-source-link="http://alma-menu--staging.s3-website-eu-west-1.amazonaws.com/main.js" type="text/javascript">
#            !function(e,t){"use strict";var n=e.ALMACR.widgets["5577db4db922930e0800001e"];n.scripts.push(function(n){!function(e){function t(s){if(n[s])return n[s].exports;var a=n[s]={i:s,l:!1,exports:{}};return e[s].call(a.exports,a,a.exports,t),a.l=!0,a.exports}var n={};return t.m=e,t.c=n,t.i=function(e){return e},t.d=function(e,n,s){t.o(e,n)||Object.defineProperty(e,n,{configurable:!1,enumerable:!0,get:s})},t.n=function(e){var n=e&&e.__esModule?function(){return e.default}:function(){return e};return t.d(n,"a",n),n},t.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},t.p="",t(t.s=0)}([function(n,s,a){try{!function(){function n(){var e="open",n=t.getElementsByClassName("alma-menu-logo")[0];return!!n&&(n.classList?n.classList.contains(e):new RegExp("(^| )"+e+"( |$)","gi").test(n.className))}function s(e){var n="open",s=t.getElementsByClassName("alma-menu-logo")[0];if(s&&e)switch(e){case"add":s.classList?s.classList.add(n):s.className+=" "+n;break;case"remove":s.classList?s.classList.remove(n):s.className=s.className.replace(new RegExp("(^|\\b)"+n.split(" ").join("|")+"(\\b|$)","gi")," ");break;default:return}}function a(){var e=""!==m.style.paddingTop?parseInt(m.style.paddingTop,10):0,t=m.getBoundingClientRect().top+m.offsetHeight+e+3;i.style.top=t+"px",i.style.height=u+"px";for(var n=0;n<c.length;n++)r[n].style.height=u+"px",c[n].style.height=u+"px"}var l=767,i=t.getElementsByClassName("alma-menu")[0],o=t.getElementsByClassName("alma-menu-close")[0],r=t.getElementsByClassName("alma-menu-section-outer"),c=t.getElementsByClassName("alma-menu-section"),u=i.scrollHeight,m=t.getElementsByClassName("alma-menu-logo")[0],p=Math.max(t.documentElement.clientWidth,e.innerWidth||0);i&&o&&m&&(o.addEventListener("click",function(e){s("remove"),p<l?i.style.display="none":i.style.height=0}),m.addEventListener("click",function(e){e.preventDefault(),n()?(s("remove"),i.style.height=0):(s("add"),p<l?i.style.display="block":a())}))}()}catch(e){}}])})}(window,document);
#           </script>
#           <style data-almacr-widget-style-source-basename="styles.css" data-almacr-widget-style-source-link="http://alma-menu--staging.s3-website-eu-west-1.amazonaws.com/styles.css">
#            #ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu a,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu div,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu h5,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu h6,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu li,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu p,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu strong,#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu ul{margin:0;padding:0;border:0;font-size:14px;line-height:17px;font-weight:400;text-decoration:none;color:#fff}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu{position:absolute;top:0;left:0;z-index:9999;width:100%;-webkit-transition:height .75s;transition:height .75s;height:0;overflow:auto;font-family:"Century Gothic",Helvetica,Arial,sans-serif}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu:after{content:"";display:block;clear:both}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section-outer{background:#333 url(https://d2wjg2uht7ar0i.cloudfront.net/586d91dbb92293128e000197/05cb97e0-b50b-0134-df79-0a9ad4d62945.jpg) repeat 100% 0;-webkit-background-size:auto 100%;background-size:auto 100%;float:left;width:34%;-webkit-box-sizing:border-box;box-sizing:border-box;width:33%/}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section-outer:first-child{background:#333 url(https://d2wjg2uht7ar0i.cloudfront.net/586d91dbb92293128e000197/07859180-b50b-0134-df79-0a9ad4d62945.jpg) repeat 100% 0;-webkit-background-size:auto 100%;background-size:auto 100%;width:33%}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section-outer:last-child{background:#333 url(https://d2wjg2uht7ar0i.cloudfront.net/586d91dbb92293128e000197/09740210-b50b-0134-df79-0a9ad4d62945.jpg) repeat 50% 0;-webkit-background-size:auto 100%;background-size:auto 100%;width:33%;border-right:none}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section{background:#333;background:rgba(0 ,0 ,0 ,.75);padding:30px 20px 25px 37px}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section:hover{background:#222;background:rgba(0 ,0 ,0 ,.6)}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section:hover .alma-menu-link-list a{color:#bbb}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section h5{margin:0 0 20px;font-family:"Century Gothic",Helvetica,Arial,sans-serif;font-size:25px;line-height:25px;font-weight:700}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-section h6{font-family:"Century Gothic",Helvetica,Arial,sans-serif;text-transform:uppercase;font-weight:700;color:#999}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .alma-menu .alma-menu-link-list{margin-bottom:5px;overflow:hidden}#ALMACR-container-ALMACR-widget-5577db4db922930e0800001e #ALMACR-widget-5577db4db922930e0800001e .a ...
#           </style>
#           <div class="alma-menu" data-almacr-jquery="false">
#            <div class="alma-menu-section-outer">
#             <div class="alma-menu-section">
#              <h5>
#               Ajassa
#              </h5>
#              <ul class="alma-menu-link-list">
#               <li>
#                <a href="https://www.aamulehti.fi/Etusivu" target="_blank" title="Pirkanmaan uutiset">
#                 <strong>
#                  Aamulehti
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Pirkanmaan uutiset
#                </a>
#               </li>
#               <li>
#                <a href="https://www.arvopaperi.fi/" target="_blank" title="Sytykkeitä sijoittamiseen">
#                 <strong>
#                  Arvopaperi
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Sytykkeitä sijoittamiseen
#                </a>
#               </li>
#               <li>
#                <a href="http://www.iltalehti.fi" target="_blank" title="Uutiset, urheilu, viihde ja lifestyle">
#                 <strong>
#                  Iltalehti.fi
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Uutiset, urheilu, viihde
#                </a>
#               </li>
#               <li>
#                <a href="http://www.iltalehti.fi/iltvuutiset/?ref=kn" target="_blank" title="Tuoreimmat uutisvideot">
#                 <strong>
#                  IL TV
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Tuoreimmat uutisvideot
#                </a>
#               </li>
#               <li>
#                <a href="https://www.kauppalehti.fi/5/i/porssi/" target="_blank" title="Talousuutiset ja pörssikurssit">
#                 <strong>
#                  Kauppalehti
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Talousuutiset ja pörssikurssit
#                </a>
#               </li>
#               <li>
#                <a href="http://www.almamedia.fi/mainostajat/mediat-ja-palvelut/paikalliset" target="_blank" title="Kaupunki- ja paikallislehdet">
#                 <strong>
#                  Kaupunki- ja paikallislehdet
#                 </strong>
#                </a>
#               </li>
#               <li>
#                <a href="https://www.lapinkansa.fi/Etusivu" target="_blank" title="Lapin uutiset">
#                 <strong>
#                  Lapin Kansa
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Lapin uutiset
#                </a>
#               </li>
#               <li>
#                <a href="http://www.iltalehti.fi/saa/" target="_blank" title="Päivän sää">
#                 <strong>
#                  Päivän sää
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Iltalehti.fi
#                </a>
#               </li>
#               <li>
#                <a href="https://www.satakunnankansa.fi/Etusivu" target="_blank" title="Satakunnan &amp; Porin uutiset">
#                 <strong>
#                  Satakunnan Kansa
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Satakunnan &amp; Porin uutiset
#                </a>
#               </li>
#               <li>
#                <a href="http://www.talouselama.fi/" target="_blank" title="Talousuutiset, taustat ja seuraukset">
#                 <strong>
#                  Talouselämä
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Talousuutiset, taustat ja seuraukset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="alma-menu-section-outer">
#             <div class="alma-menu-section">
#              <h5>
#               Vapaalla
#              </h5>
#              <ul class="alma-menu-link-list">
#               <li>
#                <a href="http://www.autotalli.com" target="_blank" title="Vaihtoautot, uudet autot, autoliikkeet">
#                 <strong>
#                  Autotalli.com
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Vaihtoautot, uudet autot
#                </a>
#               </li>
#               <li>
#                <a href="https://www.e-kontakti.fi" target="_blank" title="Suomen suurin deittisivusto">
#                 <strong>
#                  E-kontakti.fi
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Suomen suurin deittisivusto
#                </a>
#               </li>
#               <li>
#                <a href="http://www.etuovi.com" target="_blank" title="Asunnot ja sisustus">
#                 <strong>
#                  Etuovi.com
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Asunnot ja sisustus
#                </a>
#               </li>
#               <li>
#                <a href="https://www.gofinland.fi" target="_blank" title="Parhaat mökkilomat">
#                 <strong>
#                  Gofinland
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Parhaat mökkilomat
#                </a>
#               </li>
#               <li>
#                <a href="http://www.iltalehti.fi/" target="_blank" title="Viihde, lifestyle, uutiset, urheilu">
#                 <strong>
#                  Iltalehti
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Lifestyle, uutiset, urheilu
#                </a>
#               </li>
#               <li>
#                <a href="http://www.iltalehti.fi/iltv/" target="_blank" title="Ideoita ja inspiraatiota">
#                 <strong>
#                  IL TV
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Ideoita ja inspiraatiota
#                </a>
#               </li>
#               <li>
#                <a href="https://www.kauppalehti.fi/optio" target="_blank" title="Talouden henkilöt ja ilmiöt">
#                 <strong>
#                  Kauppalehti Optio
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Talouden henkilöt ja ilmiöt
#                </a>
#               </li>
#               <li>
#                <a href="https://www.kotikokki.net" target="_blank" title="Parhaat reseptit">
#                 <strong>
#                  Kotikokki
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Parhaat reseptit
#                </a>
#               </li>
#               <li>
#                <a href="https://www.mikrobitti.fi/" target="_blank" title="Tietotekniikan laitteet, palvelut ja ilmiöt">
#                 <strong>
#                  Mikrobitti
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Tietotekniikan laitteet, palvelut ja ilmiöt
#                </a>
#               </li>
#               <li>
#                <a href="http://www.rantapallo.fi" target="_blank" title="Suunnittele täydellinen matka">
#                 <strong>
#                  Rantapallo
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Matkavinkit, kohdeoppaat, matkahaut
#                </a>
#               </li>
#               <li>
#                <a href="http://www.telkku.com" target="_blank" title="Tv-ohjelmat">
#                 <strong>
#                  Telkku.com
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Tv-ohjelmat
#                </a>
#               </li>
#               <li>
#                <a href="http://www.vuokraovi.com" target="_blank" title="Vuokra-asunnot">
#                 <strong>
#                  Vuokraovi.com
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Vuokra-asunnot
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="alma-menu-section-outer">
#             <div class="alma-menu-section">
#              <p class="alma-menu-close">
#               ×
#              </p>
#              <h5>
#               Työssä
#              </h5>
#              <ul class="alma-menu-link-list">
#               <li>
#                <a href="https://www.kauppalehti.fi/uutiset/luetuimmat" target="_blank" title="Oma raha, yritykset, johtaminen">
#                 <strong>
#                  Kauppalehti
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Oma raha, yritykset, johtaminen
#                </a>
#               </li>
#               <li>
#                <a href="http://www.marmai.fi/" target="_blank" title="Alan uutiset ja ilmiöt">
#                 <strong>
#                  Markkinointi&amp;Mainonta
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Alan uutiset ja ilmiöt
#                </a>
#               </li>
#               <li>
#                <a href="https://www.monster.fi/" target="_blank" title="Avoimet työpaikat">
#                 <strong>
#                  Monster
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Avoimet työpaikat
#                </a>
#               </li>
#               <li>
#                <a href="https://www.monsterklubi.fi/" target="_blank" title="Työelämän ilmiöt">
#                 <strong>
#                  Monster Klubi
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Työelämän ilmiöt
#                </a>
#               </li>
#               <li>
#                <a href="http://www.tekniikkatalous.fi/" target="_blank" title="Teknologiauutiset ja ilmiöt">
#                 <strong>
#                  Tekniikka&amp;Talous
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Teknologiauutiset ja ilmiöt
#                </a>
#               </li>
#               <li>
#                <a href="http://www.tivi.fi/" target="_blank" title="ICT-uutiset ja -ilmiöt">
#                 <strong>
#                  Tivi
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 ICT-uutiset ja -ilmiöt
#                </a>
#               </li>
#               <li>
#               </li>
#               <li>
#                <h6>
#                 Yrityspalvelut
#                </h6>
#               </li>
#               <li>
#                <a href="http://www.almamedia.fi/yhteystiedot" target="_blank" title="Alma Media yhteystiedot">
#                 <strong>
#                  Alma Media yhteystiedot
#                 </strong>
#                </a>
#               </li>
#               <li>
#                <a href="http://www.almacareer.com/" target="_blank" title="Kansainväliset rekrytointipalvelut">
#                 <strong>
#                  Alma Career
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Kansainväliset rekrytointipalvelut
#                </a>
#               </li>
#               <li>
#                <a href="https://www.almamanu.fi/" target="_blank" title="Sanomalehtipaino ja jakelu">
#                 <strong>
#                  Alma Manu
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Sanomalehtipaino ja jakelu
#                </a>
#               </li>
#               <li>
#                <a href="https://tietopalvelut.kauppalehti.fi/" target="_blank" title="Yritykset, kiinteistöt, henkilöt">
#                 <strong>
#                  Kauppalehti Tietopalvelut
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Yritykset, kiinteistöt, henkilöt
#                </a>
#               </li>
#               <li>
#                <a href="https://toimitilat.kauppalehti.fi/" target="_blank" title="Yritysten liiketilat">
#                 <strong>
#                  Kauppalehti Toimitilat
#                 </strong>
#                 <span class="alma-menu-dash">
#                  –
#                 </span>
#                 Yritysten liiketilat
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </article>
#         </div>
#         <div id="ALMACR-widget-5577db4db922930e0800001e-jquery-target">
#         </div>
#         <script class="ALMACR-base-scripts">
#          !function(e,t){"use strict";function o(){return"object"==typeof e.ALMA&&"function"==typeof e.ALMA.require&&"function"==typeof e.ALMA.define&&"undefined"!=typeof e.ALMA.define.amd}function n(t,o){e.ALMACR.usesContentRouterAMD=!0,e.ALMACR.waitForModuleLoader=1,e.console.log&&e.console.log("[ContentRouter] Begin AMD loader download...");var n="https://cdn.almamedia.fi/script/require/2.3.3%2Bprototypejs-support/require.min.js";d(n,t,o)}function d(e,o,n){var d=t.createElement("script");d.src=e;var i=t.getElementById(o),a=!1;d.onload=d.onreadystatechange=function(){a||this.readyState&&"loaded"!==this.readyState&&"complete"!==this.readyState||(a=!0,n(),d.onload=d.onreadystatechange=null,i.removeChild(d))},i.appendChild(d)}var i=e.ALMACR.widgets["5577db4db922930e0800001e"];if(i.active=!1,i.hidden=!0,i.id="5577db4db922930e0800001e",i.name="Alma Menu",i.publisher={name:"Alma-Media",id:"5577db0eb922930e0800001d"},i.templateVersion="0.0.1",i.elementId="ALMACR-widget-5577db4db922930e0800001e",i.domObject=t.getElementById("ALMACR-widget-5577db4db922930e0800001e"),i.log=[],i.init=function(t){var d=20;o()?(e.ALMACR.usesContentRouterAMD?e.console.log("[ContentRouter][Widget][5577db4db922930e0800001e] Alma AMD loader available via Content Router. Starting widget..."):e.console.log("[ContentRouter][Widget][5577db4db922930e0800001e] Alma AMD loader available via external config. Starting widget..."),i.startWidget(t)):e.ALMACR.waitForModuleLoader&&e.ALMACR.waitForModuleLoader<=d?(e.console.log&&e.console.log("[ContentRouter][Widget][5577db4db922930e0800001e] Alma AMD loader is already being downloaded... postponing widget execution..."),e.setTimeout(function(){e.ALMACR.waitForModuleLoader++,i.init(t)},1e3)):(e.console.log&&e.console.log("[ContentRouter] No Alma AMD loader present."),n("ALMACR-widget-5577db4db922930e0800001e-jquery-target",function(){e.console.log&&e.console.log("[ContentRouter] Alma AMD loader has now been downloaded!"),i.startWidget(t)}))},i.startWidget=function(t){e.ALMACR.widgets["5577db4db922930e0800001e"].active=!0,e.ALMACR.widgets["5577db4db922930e0800001e"].hidden=!1,e.ALMACR.widgets["5577db4db922930e0800001e"].scripts.forEach(function(e){e(t)})},"querySelector"in t){var a="1.11.1";e.jQuery?i.init(e.jQuery):e.ALMACR.jQuery?i.init(e.ALMACR.jQuery):d("https://ajax.googleapis.com/ajax/libs/jquery/"+a+"/jquery.min.js","ALMACR-widget-5577db4db922930e0800001e-jquery-target",function(){e.jQuery&&(e.ALMACR.jQuery=e.jQuery,e.jQuery.noConflict(!0),i.init(e.ALMACR.jQuery))})}else i.hidden=!0}(window,document);
#         </script>
#         <script>
#         </script>
#        </div>
#        <!--<![endif]-->
#        <!--[if lt IE 9]><!-->
#        <script>
#         /* log as non active etc */
#        </script>
#        <!--<![endif]-->
#        <!--/ ALMA CR WIDGET -->
#        <!-- ALMACR:CONTENT_OK -->
#       </div>
#      </div>
#      <script type="text/javascript">
#       window.showEnreach = false;
#       window.showMadsTags = false;
#       window.emediateDomain = 'https://eas.almamedia.fi';
#       window.showEmediate = false;
#      </script>
#      <!--Ads Top banner -->
#      <div class="l-top-banner text-center" id="jsTopBanner">
#       <div id="almad-parade-1">
#        <script>
#         if (typeof window.ALMA != "undefined" && typeof window.ALMA.ad != "undefined") {window.ALMA.ad.loadAd('almad-parade-1');}
#        </script>
#       </div>
#       <script src="//snail.crometenterprise.com/timeout/timeout.php?timeout=1000000">
#       </script>
#      </div>
#      <div class="row">
#       <div class="navbar-header col-xs-12 col-sm-1 col-md-3 col-lg-3">
#        <a href="/">
#         <img alt="Vuokraovi.com logo" class="logo" onerror="this.onerror=null; this.src='/img/logo/vo_logo_white.png'" src="/img/logo/vo_logo_white.svg"/>
#        </a>
#       </div>
#       <div class="hidden-xs col-md-9 col-lg-9 margin-top-5">
#        <ul class="nav navbar-nav pull-right">
#         <li class="nav-link">
#          <a href="/haku/vuokra-asunnot">
#           <img alt="Vuokra-asunnot" class="arrow-right" onerror="this.onerror=null; this.src='/img/assets/arrow_right_orange.png'" src="/img/assets/arrow_right_orange.svg">
#            Vuokra-asunnot
#           </img>
#          </a>
#         </li>
#         <li class="nav-link">
#          <a href="https://www.gofinland.fi/vuokramokit">
#           <img alt="Vuokramökit" class="arrow-right" onerror="this.onerror=null; this.src='/img/assets/arrow_right_green.png'" src="/img/assets/arrow_right_green.svg">
#            Vuokramökit
#           </img>
#          </a>
#         </li>
#         <li class="nav-link">
#          <a href="/vuokranantajille">
#           <img alt="Vuokranantajille" class="arrow-right" onerror="this.onerror=null; this.src='/img/assets/arrow_right_pink.png'" src="/img/assets/arrow_right_pink.svg"/>
#           Vuokranantajille
#          </a>
#         </li>
#         <li class="menu-alma-logo hidden-sm">
#          <a class="alma-menu-logo" href="#void">
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="hidden-xs col-sm-2">
#       </div>
#      </div>
#     </div>
#     <!-- Extend header background above the right advertisement-->
#     <div class="hidden-xs hidden-lg" id="headerExtender">
#     </div>
#    </nav>
#    <!--  Toolbar mobile -->
#    <div class="col-sm-12 toolbar-mobile visible-xs toolbar-box-shadow">
#     <div class="navigation-menu-toggle col-xs-1 icon-menu" id="leftMenuToggle">
#     </div>
#     <a class="pull-right pad-right-10 icon-c-personal-info pad-top-7" href="/login.action">
#     </a>
#    </div>
#    <!--  Toolbar Desktop -->
#    <div class="col-sm-12 toolbar hidden-xs toolbar-box-shadow">
#     <div class="container pad-right-0 pad-left-0 flexible-container">
#      <ul class="list-toolbar-links list-unstyled list-inline list-separated pull-right">
#       <li>
#        <a href="/secured/register.action">
#         Rekisteröidy
#        </a>
#       </li>
#       <li>
#        <a href="/login.action">
#         Kirjaudu sisään
#        </a>
#       </li>
#       <li class="language-selector">
#        <ul class="list-unstyled list-inline list-languages">
#         <li class="language language-fi active">
#          <a href="?locale=fi&amp;page=1" title="Suomeksi">
#          </a>
#         </li>
#         <li class="language language-en ">
#          <a href="?locale=en&amp;page=1" title="In English">
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- Extend toolbar background above the right advertisement-->
#     <div class="hidden-xs hidden-lg box-shadowed" id="toolbarExtender">
#     </div>
#    </div>
#    <!--  Container starts -->
#    <div class="container pad-right-0 pad-left-0 flexible-container">
#     <div class="col-xs-12 notificationForOldWindowsPhone notification notification-error" style="display:none;">
#      <div class="text-center wrapper">
#       <ul class="list-unstyled list-inline">
#        <li class="icon">
#         <span class="icon glyphicon glyphicon-warning-sign font-30">
#         </span>
#        </li>
#        <li class="text">
#         Käyttämäsi Windows Phone -käyttöjärjestelmän versio on vanhentunut eikä palvelu välttämättä toimi puhelimellasi parhaalla mahdollisella tavalla.
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!--[if lte IE 8]>
# <div class="col-xs-12 notification notification-error">
#   <div class="text-center wrapper">
#     <ul class="list-unstyled list-inline">
#       <li class="icon"><span class="icon glyphicon glyphicon-warning-sign font-30"></span></li>
#       <li class="text">Käyttämäsi selain on vanhentunut, eikä uudistunut Vuokraovi.com välttämättä toimi käyttämälläsi selainversiolla. Päivitä selaimesi <a href="http://browsehappy.com/" >täällä</a>.</li>
#     </ul>
#   </div>
# </div>
# <![endif]-->
#     <ol class="breadcrumb">
#      <li>
#       <a href="/">
#        Vuokraovi
#       </a>
#      </li>
#      <li class="active">
#       Listasivu
#      </li>
#     </ol>
#     <!-- List page content column -->
#     <div id="listContent">
#      <div id="highlighterRentalsBanner">
#      </div>
#      <!-- Hakuehdoilla löytyy -->
#      <div class="row" id="listNavigation">
#       <div class="col-xs-12 col-sm-7 col-md-8">
#        <h1 class="col-xs-12 no-style" style="font-size: 20px">
#         Hakuehdoilla löytyy
#         <span class="bold">
#          10 358 asuntoa
#         </span>
#        </h1>
#       </div>
#       <div class="hidden-xs">
#        <div class="col-sm-5 col-md-4">
#         <form action="/haku/vuokra-asunnot" class="pull-right" method="get">
#          <input name="searchtype" type="hidden" value="new"/>
#          <button class="btn btn-orange btn-sm btn-angle" type="submit">
#           Uusi haku
#          </button>
#         </form>
#         <form action="/haku/vuokra-asunnot" class="pull-right" method="get">
#          <button class="btn btn-orange btn-sm btn-angle margin-right-10" type="submit">
#           Muokkaa hakua
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <!-- Hakuehdoilla löytyy ENDS -->
#      <div class="row">
#       <div class="col-xs-12 col-sm-7 col-md-7 margin-bottom-10">
#        <h2 class="no-style font-14">
#         <strong>
#          Hakuehdot:
#         </strong>
#         vuokrakohteet
#        </h2>
#       </div>
#       <div class="visible-xs pad-top-5">
#        <div class="row">
#         <div class="col-xs-12">
#          <form action="/haku/vuokra-asunnot" class="pad-left-10" method="get" style="float:left;">
#           <button class="btn btn-orange btn-sm btn-angle margin-right-10" type="submit">
#            Muokkaa hakua
#           </button>
#          </form>
#          <form action="/haku/vuokra-asunnot" method="get" style="float:left;">
#           <input name="searchtype" type="hidden" value="new"/>
#           <button class="btn btn-orange btn-sm btn-angle" type="submit">
#            Uusi haku
#           </button>
#          </form>
#         </div>
#        </div>
#       </div>
#       <div class="list-pager col-xs-12 col-sm-5 col-md-5">
#        <ul class="pagination ">
#         <li>
#          <a class="list-pager-button" href="#" style="cursor: default;">
#           <img alt="Edellinen" src="/img/controls/arrow_disabled_left.svg"/>
#          </a>
#         </li>
#         <li>
#          <span>
#           Sivu:
#          </span>
#         </li>
# ...
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Parhaat mökkilomat
#               </a>
#              </li>
#              <li>
#               <a href="http://www.iltalehti.fi/" target="_blank" title="Viihde ja lifestyle, uutiset ja urheilu">
#                <strong>
#                 Iltalehti
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Lifestyle, uutiset, urheilu
#               </a>
#              </li>
#              <li>
#               <a href="https://www.kauppalehti.fi/optio" target="_blank" title="Talouden henkilöt ja ilmiöt">
#                <strong>
#                 Kauppalehti Optio
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Talouden henkilöt ja ilmiöt
#               </a>
#              </li>
#              <li>
#               <a href="https://www.kotikokki.net" target="_blank" title="Parhaat reseptit">
#                <strong>
#                 Kotikokki
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Parhaat reseptit
#               </a>
#              </li>
#              <li>
#               <a href="https://www.mikrobitti.fi/" target="_blank" title="Tietotekniikan laitteet, palvelut ja ilmiöt">
#                <strong>
#                 Mikrobitti
#                </strong>
#                <span class="alma-menu-dash">
#                 –
#                </span>
#                Tietotekniikan laitteet, palvelut ja ilmiöt
#               </a>
#              </li>
#              <li>
#               <a href="http://www.vuokraovi.com" target="_blank" title="Vuokra-asunnot ja mökit">
#                <strong>
#                 Vuokraovi.com
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Vuokra-asunnot ja mökit
#               </a>
#              </li>
#              <li class="alma-footer-show-all">
#               <p>
#                Näytä kaikki
#               </p>
#              </li>
#             </ul>
#            </div>
#            <div class="alma-footer-section row-last">
#             <h5>
#              Työssä
#             </h5>
#             <ul class="alma-footer-link-list">
#              <li>
#               <a href="https://www.kauppalehti.fi/uutiset/luetuimmat" target="_blank" title="Oma raha, yritykset, johtaminen">
#                <strong>
#                 Kauppalehti
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Oma raha, yritykset, johtaminen
#               </a>
#              </li>
#              <li>
#               <a href="http://www.marmai.fi/" target="_blank" title="Alan uutiset ja ilmiöt">
#                <strong>
#                 Markkinointi &amp; Mainonta
#                </strong>
#                <span class="alma-menu-dash">
#                 –
#                </span>
#                Alan uutiset ja ilmiöt
#               </a>
#              </li>
#              <li>
#               <a href="https://www.monster.fi/" target="_blank" title="Avoimet työpaikat">
#                <strong>
#                 Monster
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Avoimet työpaikat
#               </a>
#              </li>
#              <li>
#               <a href="http://www.tekniikkatalous.fi/" target="_blank" title="Teknologiauutiset ja ilmiöt">
#                <strong>
#                 Tekniikka &amp; Talous
#                </strong>
#                <span class="alma-menu-dash">
#                 –
#                </span>
#                Teknologiauutiset ja ilmiöt
#               </a>
#              </li>
#              <li>
#               <a href="http://www.tivi.fi/" target="_blank" title="ICT-uutiset ja -ilmiöt">
#                <strong>
#                 Tivi
#                </strong>
#                <span class="alma-menu-dash">
#                 –
#                </span>
#                ICT-uutiset ja -ilmiöt
#               </a>
#              </li>
#              <li>
#              </li>
#              <li>
#               <h6>
#                Yrityspalvelut
#               </h6>
#              </li>
#              <li>
#               <a href="http://www.almacareer.com/" target="_blank" title="Kansainväliset rekrytointipalvelut">
#                <strong>
#                 Alma Career
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Kansainväliset rekrytointipalvelut
#               </a>
#              </li>
#              <li>
#               <a href="https://www.almamanu.fi/" target="_blank" title="Sanomalehtipaino ja jakelu">
#                <strong>
#                 Alma Manu
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Sanomalehtipaino ja jakelu
#               </a>
#              </li>
#              <li>
#               <a href="https://tietopalvelut.kauppalehti.fi/" target="_blank" title="Yritykset, kiinteistöt, henkilöt">
#                <strong>
#                 Kauppalehti Tietopalvelut
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Yritykset, kiinteistöt, henkilöt
#               </a>
#              </li>
#              <li>
#               <a href="https://toimitilat.kauppalehti.fi/" target="_blank" title="Yritysten liiketilat">
#                <strong>
#                 Kauppalehti Toimitilat
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Yritysten liiketilat
#               </a>
#              </li>
#              <li>
#               <a href="https://www.monsterklubi.fi/" target="_blank" title="Työelämän ilmiöt">
#                <strong>
#                 Monster Klubi
#                </strong>
#                <span class="alma-footer-dash">
#                 –
#                </span>
#                Työelämän ilmiöt
#               </a>
#              </li>
#              <li class="alma-footer-show-all">
#               <p>
#                Näytä kaikki
#               </p>
#              </li>
#             </ul>
#            </div>
#            <div class="alma-footer-bottom">
#             <div class="alma-footer-section">
#              <a href="http://www.almamedia.fi/" target="_blank" title="Alma Media">
#               © Alma Media Oyj
#               <span class="alma-footer-copyright-year">
#                2016
#               </span>
#              </a>
#             </div>
#             <div class="alma-footer-section">
#              <a href="http://www.almamedia.fi/tietosuoja" target="_blank" title="Tietosuoja">
#               Tietosuoja
#              </a>
#             </div>
#             <div class="alma-footer-section">
#              <a href="http://www.almamedia.fi/yhteystiedot" target="_blank" title="Alma Media yhteystiedot">
#               Alma Media yhteystiedot
#              </a>
#             </div>
#            </div>
#           </div>
#           <script data-almacr-widget-script-id="37vftxj" data-almacr-widget-script-source-basename="main.js" data-almacr-widget-script-source-link="http://alma-footer--staging.s3-website-eu-west-1.amazonaws.com/main.js" type="text/javascript">
#            !function(e,t){"use strict";var n=e.ALMACR.widgets["5577db28b922930e04000019"];n.scripts.push(function(n){!function(e){function t(a){if(n[a])return n[a].exports;var l=n[a]={i:a,l:!1,exports:{}};return e[a].call(l.exports,l,l.exports,t),l.l=!0,l.exports}var n={};return t.m=e,t.c=n,t.i=function(e){return e},t.d=function(e,n,a){t.o(e,n)||Object.defineProperty(e,n,{configurable:!1,enumerable:!0,get:a})},t.n=function(e){var n=e&&e.__esModule?function(){return e.default}:function(){return e};return t.d(n,"a",n),n},t.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},t.p="",t(t.s=0)}([function(n,a,l){try{!function(){function n(){for(var e=[],n=t.getElementsByClassName("alma-footer-link-list"),a=0;a<n.length;a++)e.push(n[a].clientHeight);return Math.max.apply(null,e)}function a(e){for(var t=0;t<e.length;t++)e[t].classList.contains("alma-footer-show-all")?e[t].parentNode.removeChild(e[t]):e[t].style.display=""}function l(e){for(var n=t.getElementsByClassName("alma-footer-link-list"),a=0;a<n.length;a++){n[a].style.maxHeight=e;for(var l=n[a].getElementsByTagName("li"),r=0;r<l.length;r++)l[r].classList.contains("alma-footer-show-all")?l[r].parentNode.removeChild(l[r]):l[r].style.display=""}}var r=767,o=5,i=Math.max(t.documentElement.clientWidth,e.innerWidth||0),s=(Math.max(t.documentElement.clientHeight,e.innerHeight||0),n());i<=r&&(o=3);for(var c=t.getElementsByClassName("alma-footer-link-list"),m=0;m<c.length;m++)for(var f=c[m].getElementsByTagName("li"),u=0;u<f.length;u++)u>=o&&!f[u].classList.contains("alma-footer-show-all")&&!f[u].classList.contains("alma-footer-hide")&&(f[u].style.display="none");for(var h=0;h<c.length;h++)c[h].style.minHeight=String(n()).concat("px");t.getElementsByClassName("alma-footer-copyright-year")[0].innerHTML=(new Date).getFullYear();for(var g=t.getElementsByClassName("alma-footer-show-all"),d=0;d<g.length;d++)g[d].addEventListener("click",function(e){i<r?a(e.path[2].getElementsByTagName("li")):l(s)})}()}catch(e){}}])})}(window,document);
#           </script>
#          </article>
#         </div>
#         <div id="ALMACR-widget-5577db28b922930e04000019-jquery-target">
#         </div>
#         <script class="ALMACR-base-scripts">
#          !function(e,t){"use strict";function o(){return"object"==typeof e.ALMA&&"function"==typeof e.ALMA.require&&"function"==typeof e.ALMA.define&&"undefined"!=typeof e.ALMA.define.amd}function n(t,o){e.ALMACR.usesContentRouterAMD=!0,e.ALMACR.waitForModuleLoader=1,e.console.log&&e.console.log("[ContentRouter] Begin AMD loader download...");var n="https://cdn.almamedia.fi/script/require/2.3.3%2Bprototypejs-support/require.min.js";i(n,t,o)}function i(e,o,n){var i=t.createElement("script");i.src=e;var d=t.getElementById(o),a=!1;i.onload=i.onreadystatechange=function(){a||this.readyState&&"loaded"!==this.readyState&&"complete"!==this.readyState||(a=!0,n(),i.onload=i.onreadystatechange=null,d.removeChild(i))},d.appendChild(i)}var d=e.ALMACR.widgets["5577db28b922930e04000019"];if(d.active=!1,d.hidden=!0,d.id="5577db28b922930e04000019",d.name="Alma Footer",d.publisher={name:"Alma-Media",id:"5577db0eb922930e0800001d"},d.templateVersion="0.0.1",d.elementId="ALMACR-widget-5577db28b922930e04000019",d.domObject=t.getElementById("ALMACR-widget-5577db28b922930e04000019"),d.log=[],d.init=function(t){var i=20;o()?(e.ALMACR.usesContentRouterAMD?e.console.log("[ContentRouter][Widget][5577db28b922930e04000019] Alma AMD loader available via Content Router. Starting widget..."):e.console.log("[ContentRouter][Widget][5577db28b922930e04000019] Alma AMD loader available via external config. Starting widget..."),d.startWidget(t)):e.ALMACR.waitForModuleLoader&&e.ALMACR.waitForModuleLoader<=i?(e.console.log&&e.console.log("[ContentRouter][Widget][5577db28b922930e04000019] Alma AMD loader is already being downloaded... postponing widget execution..."),e.setTimeout(function(){e.ALMACR.waitForModuleLoader++,d.init(t)},1e3)):(e.console.log&&e.console.log("[ContentRouter] No Alma AMD loader present."),n("ALMACR-widget-5577db28b922930e04000019-jquery-target",function(){e.console.log&&e.console.log("[ContentRouter] Alma AMD loader has now been downloaded!"),d.startWidget(t)}))},d.startWidget=function(t){e.ALMACR.widgets["5577db28b922930e04000019"].active=!0,e.ALMACR.widgets["5577db28b922930e04000019"].hidden=!1,e.ALMACR.widgets["5577db28b922930e04000019"].scripts.forEach(function(e){e(t)})},"querySelector"in t){var a="1.11.1";e.jQuery?d.init(e.jQuery):e.ALMACR.jQuery?d.init(e.ALMACR.jQuery):i("https://ajax.googleapis.com/ajax/libs/jquery/"+a+"/jquery.min.js","ALMACR-widget-5577db28b922930e04000019-jquery-target",function(){e.jQuery&&(e.ALMACR.jQuery=e.jQuery,e.jQuery.noConflict(!0),d.init(e.ALMACR.jQuery))})}else d.hidden=!0}(window,document);
#         </script>
#         <script>
#         </script>
#        </div>
#        <!--<![endif]-->
#        <!--[if lt IE 9]><!-->
#        <script>
#         /* log as non active etc */
#        </script>
#        <!--<![endif]-->
#        <!--/ ALMA CR WIDGET -->
#        <!-- ALMACR:CONTENT_OK -->
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <!-- content -->
#   <div class="visible-xs navbar navbar-default" id="mobileListToolbar">
#    <form action="/vuokra-asunnot" method="post" style="display: inline">
#     <div class="col-xs-8 col-sm-8 pad-top-8 mobile-ordering-select">
#      <select class="select select-default" data-width="100%" name="listorder" onchange="submit();">
#       <option selected="selected" value="11">
#        uusimmat ilmoitukset ensin
#       </option>
#       <option value="12">
#        vanhimmat ilmoitukset ensin
#       </option>
#       <option value="13">
#        asuntotyypin mukaan a &gt; ö
#       </option>
#       <option value="14">
#        asuntotyypin mukaan ö &gt; a
#       </option>
#       <option value="15">
#        vuosiluvun mukaan vanhin ensin
#       </option>
#       <option value="16">
#        vuosiluvun mukaan uusin ensin
#       </option>
#       <option value="17">
#        pinta-alan mukaan pienin ensin
#       </option>
#       <option value="18">
#        pinta-alan mukaan suurin ensin
#       </option>
#       <option value="19">
#        hinnan mukaan halvin ensin
#       </option>
#       <option value="20">
#        hinnan mukaan kallein ensin
#       </option>
#       <option value="21">
#        sijainnin mukaan a &gt; ö
#       </option>
#       <option value="22">
#        sijainnin mukaan ö &gt; a
#       </option>
#       <option value="23">
#        esittelyajan mukaan
#       </option>
#       <option value="24">
#        välittäjän mukaan a &gt; ö
#       </option>
#       <option value="25">
#        välittäjän mukaan ö &gt; a
#       </option>
#       <option value="26">
#        vapautumisen mukaan nouseva
#       </option>
#      </select>
#      <label class="caret">
#      </label>
#     </div>
#     <div class="col-xs-4 col-sm-4 pad-right-0 mobile-list-style-options">
#      <div class="btn-group pull-right list-style-selector">
#       <a class="btn btn-default btn-list active" href="/vuokra-asunnot?page=1&amp;pageType=list">
#        <span class="icon-list2">
#        </span>
#       </a>
#       <a class="btn btn-default " href="/vuokra-asunnot?page=1&amp;pageType=grid">
#        <span class="icon-grid" style="font-size: 26px;">
#        </span>
#       </a>
#      </div>
#     </div>
#    </form>
#   </div>
#   <!-- Mobile fixed toolbar placeholder ENDS-->
#   <script src="/js/spring.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var sp_s = { "s":"vuokraovi", "r": document.location.href }
#         var sp_e0 = [];
#
#
#         sp_e0.push({ "cp":"listasivut/vuokra_asunnot" });
#
#         sp_e0.push({ "cp":"vuokra_asunnot/listasivu" });
#
#         spring.c(sp_s,sp_e0);
#   </script>
#   <noscript>
#    <img alt="" src="https://ssl-vuokraovi.spring-tns.net/j0=,,,;+,,cp=listasivut/vuokra_asunnot;+,cp=vuokra_asunnot/listasivu;;;;"/>
#   </noscript>
#   <!-- All common scripts combined together (wro.xml) to achieve better performance VUOKRAOVI-5303 -->
#   <script src="/js/common-scripts.js">
#   </script>
#   <script src="/js/social_bookmarking.js" type="text/javascript">
#   </script>
#  </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-4f738fca61c2> in <module>()
#      11     print(parsed_html.prettify())
#      12
# ---> 13     rows = parsed_html.find('table', {'id':'itemList'}).find('tbody').findAll('tr', {'class': ['evenRow', 'oddRow']})
#      14
#      15     row_index = 0
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
apartment_index = 0
# Second we get data from individual aparment pages.
# We need to do this while not all the information like build year
# is not available on the apartment listning page.
# Ex. http://www.vuokraovi.com/vuokra-asunto/helsinki/kalasatama/kerrostalo/yksio/484562?entryPoint=fromSearch&rentalIndex=1
print 'Fetching data for: ' + str(table.find({'build_year': ''}).count()) + ' houses.\n'
for apartment in table.find({'build_year': ''}):
  apartment_index = apartment_index + 1
  html = requests.get('http://www.vuokraovi.com' + apartment['url'], cookies=cookie)
  parsed_html = BeautifulSoup(html.text)
  try:
    apartment['rental_service'] = parsed_html.find('div', {'id':'rentalCardTenantInfo'}).find('a').text
  except:
    #print '\n\033[1mFailed to fetch rental service data for url:\n\033[0m http://www.vuokraovi.com' + apartment['url']
    apartment['rental_service'] = ''
  #print apartment['rental_service']
  try:
    rows = parsed_html.find('table', {'class':'rentaltable'}).find('tbody').findAll('tr', {'class': ['evenRow', 'odd']})
    row_index = 0
    apartment['street_address'] = apartment['postal_code'] = apartment['building'] = apartment['description'] = apartment['build_year'] = ''
    for row in rows:
      row_index = row_index + 1
      heading = row.find('th').text
      # Apartment address.
      if heading == 'Sijainti:':
        apartment['street_address'] = row.find('td').find('span', {'itemprop': 'streetAddress'}).text
        m = re.search('([0-9]{5})', row.find('td').find('span', {'itemprop': 'addressLocality'}).text)
        apartment['postal_code'] = m.group(1)
      # Apartment type.
      if heading == 'Tyyppi:':
        apartment['building'] = row.find('td').text
      # Apartment type.
      if heading == 'Kuvaus:':
        apartment['description'] = row.find('td').text
      # Apartment build year.
      if heading == 'Rakennusvuosi:':
        apartment['build_year'] = row.find('td').text
    if apartment['aid'] != '':
      # Update the existing database record
      # with the new data we've fetched.
      table.update({'aid':apartment['aid']}, {
        '$set': {
          'street_address': apartment['street_address'],
          'postal_code': apartment['postal_code'],
          'building': apartment['building'],
          'description': apartment['description'],
          'rental_service': apartment['rental_service'],
          'build_year': apartment['build_year']
        }
      })
    if (apartment_index % 10) == 0:
      print 'Fetched data for ' + str(apartment_index) + ' houses.'
  except:
    print '\n\033[1mFailed to fetch data for url:\n\033[0m http://www.vuokraovi.com' + apartment['url']

print '\n\033[1mAll done! Bye bye.\n\033[0m'

# You can export the data from database with this kind of command.
# mongoexport --db housing_data --collection etuovi  --csv -f aid,street_address,postal_code,building,description,rent_nr,size_nr,build_year,url > data.csv
